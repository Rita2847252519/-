# %%
import turtle
turtle.setup(700,400,300,300)
turtle.penup()
turtle.fd(-225)
turtle.seth(90)
turtle.pendown()
turtle.pensize(2)
turtle.fillcolor("red")
turtle.begin_fill()
turtle.fd(150)
turtle.seth(0)
turtle.fd(450)
turtle.seth(-90)
turtle.fd(300)
turtle.seth(180)
turtle.fd(450)
turtle.seth(90)
turtle.fd(150)
turtle.end_fill()
turtle.penup()
turtle.fd(90)
turtle.seth(0)
turtle.fd(45)
turtle.pendown()
turtle.pencolor("yellow")
turtle.fillcolor("yellow")
turtle.begin_fill()
turtle.fd(60)
turtle.seth(-144)
turtle.fd(60)
turtle.seth(72)
turtle.fd(60)
turtle.seth(-72)
turtle.fd(60)
turtle.seth(144)
turtle.fd(60)
turtle.end_fill()
turtle.penup()
turtle.seth(0)
turtle.fd(120)
turtle.seth(90)
turtle.fd(12)
turtle.seth(0)
turtle.pendown()
turtle.pencolor("yellow")
turtle.fillcolor("yellow")
turtle.begin_fill()
turtle.fd(15)
turtle.seth(-144)
turtle.fd(15)
turtle.seth(72)
turtle.fd(15)
turtle.seth(-72)
turtle.fd(15)
turtle.seth(144)
turtle.fd(15)
turtle.end_fill()
turtle.penup()
turtle.seth(0)
turtle.seth(90)
turtle.fd(25)
turtle.seth(180)
turtle.fd(40)
turtle.seth(0)
turtle.pendown()
turtle.pencolor("yellow")
turtle.fillcolor("yellow")
turtle.begin_fill()
turtle.fd(15)
turtle.seth(-144)
turtle.fd(15)
turtle.seth(72)
turtle.fd(15)
turtle.seth(-72)
turtle.fd(15)
turtle.seth(144)
turtle.fd(15)
turtle.end_fill()
turtle.penup()
turtle.seth(-90)
turtle.fd(60)
turtle.seth(0)
turtle.fd(42)
turtle.pendown()
turtle.pencolor("yellow")
turtle.fillcolor("yellow")
turtle.begin_fill()
turtle.fd(15)
turtle.seth(-144)
turtle.fd(15)
turtle.seth(72)
turtle.fd(15)
turtle.seth(-72)
turtle.fd(15)
turtle.seth(144)
turtle.fd(15)
turtle.end_fill()
turtle.penup()
turtle.seth(-90)
turtle.fd(25)
turtle.seth(180)
turtle.fd(25)
turtle.seth(0)
turtle.pendown()
turtle.pencolor("yellow")
turtle.fillcolor("yellow")
turtle.begin_fill()
turtle.fd(15)
turtle.seth(-144)
turtle.fd(15)
turtle.seth(72)
turtle.fd(15)
turtle.seth(-72)
turtle.fd(15)
turtle.seth(144)
turtle.fd(15)
turtle.end_fill()
